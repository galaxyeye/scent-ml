# %%
import os
import sys
os.environ['PYSPARK_PYTHON'] = sys.executable
os.environ['PYSPARK_DRIVER_PYTHON'] = sys.executable

from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("DataLoadTest").getOrCreate()
sc = spark.sparkContext
sc.setLogLevel("INFO")

# %%
path = "../../data/dom/amazon.dataset.csv.11.25.100.csv"
df = spark.read.options(header='True', inferSchema='True')\
    .csv(path)

# %%
df.printSchema()
# Out:
# root
#  |-- label: integer (nullable = true)
#  |-- top-g0: double (nullable = true)
#  |-- top-g1: double (nullable = true)
#  |-- top-g2: double (nullable = true)
#  |-- top-g3: double (nullable = true)
#  |-- left-g0: integer (nullable = true)
#  |-- left-g1: integer (nullable = true)
#  |-- left-g2: integer (nullable = true)
#  |-- left-g3: integer (nullable = true)
#  |-- width-g0: integer (nullable = true)
#  |-- width-g1: integer (nullable = true)
#  |-- width-g2: integer (nullable = true)
#  |-- width-g3: integer (nullable = true)
#  |-- height-g0: integer (nullable = true)
#  |-- height-g1: integer (nullable = true)
#  |-- height-g2: integer (nullable = true)
#  |-- height-g3: integer (nullable = true)
#  |-- char-g0: integer (nullable = true)
#  |-- char-g1: integer (nullable = true)
#  |-- char-g2: integer (nullable = true)
#  |-- char-g3: integer (nullable = true)
#  |-- txt_nd-g0: integer (nullable = true)
#  |-- txt_nd-g1: integer (nullable = true)
#  |-- txt_nd-g2: integer (nullable = true)
#  |-- txt_nd-g3: integer (nullable = true)
#  |-- img-g0: integer (nullable = true)
#  |-- img-g1: integer (nullable = true)
#  |-- img-g2: integer (nullable = true)
#  |-- img-g3: integer (nullable = true)
#  |-- a-g0: integer (nullable = true)
#  |-- a-g1: integer (nullable = true)
#  |-- a-g2: integer (nullable = true)
#  |-- a-g3: integer (nullable = true)
#  |-- sibling-g0: integer (nullable = true)
#  |-- sibling-g1: integer (nullable = true)
#  |-- sibling-g2: integer (nullable = true)
#  |-- sibling-g3: integer (nullable = true)
#  |-- child-g0: integer (nullable = true)
#  |-- child-g1: integer (nullable = true)
#  |-- child-g2: integer (nullable = true)
#  |-- child-g3: integer (nullable = true)
#  |-- dep-g0: integer (nullable = true)
#  |-- dep-g1: integer (nullable = true)
#  |-- dep-g2: integer (nullable = true)
#  |-- dep-g3: integer (nullable = true)
#  |-- seq-g0: integer (nullable = true)
#  |-- seq-g1: integer (nullable = true)
#  |-- seq-g2: integer (nullable = true)
#  |-- seq-g3: integer (nullable = true)
#  |-- txt_dns-g0: integer (nullable = true)
#  |-- txt_dns-g1: integer (nullable = true)
#  |-- txt_dns-g2: integer (nullable = true)
#  |-- txt_dns-g3: integer (nullable = true)
#  |-- pid-g0: integer (nullable = true)
#  |-- pid-g1: integer (nullable = true)
#  |-- pid-g2: integer (nullable = true)
#  |-- pid-g3: integer (nullable = true)
#  |-- tag-g0: integer (nullable = true)
#  |-- tag-g1: integer (nullable = true)
#  |-- tag-g2: integer (nullable = true)
#  |-- tag-g3: integer (nullable = true)
#  |-- nd_id-g0: integer (nullable = true)
#  |-- nd_id-g1: integer (nullable = true)
#  |-- nd_id-g2: integer (nullable = true)
#  |-- nd_id-g3: double (nullable = true)
#  |-- nd_cs-g0: double (nullable = true)
#  |-- nd_cs-g1: integer (nullable = true)
#  |-- nd_cs-g2: integer (nullable = true)
#  |-- nd_cs-g3: integer (nullable = true)
#  |-- ft_sz-g0: integer (nullable = true)
#  |-- ft_sz-g1: double (nullable = true)
#  |-- ft_sz-g2: double (nullable = true)
#  |-- ft_sz-g3: double (nullable = true)
#  |-- color-g0: double (nullable = true)
#  |-- color-g1: integer (nullable = true)
#  |-- color-g2: integer (nullable = true)
#  |-- color-g3: integer (nullable = true)
#  |-- b_bolor-g0: integer (nullable = true)
#  |-- b_bolor-g1: integer (nullable = true)
#  |-- b_bolor-g2: integer (nullable = true)
#  |-- b_bolor-g3: integer (nullable = true)
#  |-- rtop-g0: integer (nullable = true)
#  |-- rtop-g1: double (nullable = true)
#  |-- rtop-g2: integer (nullable = true)
#  |-- rtop-g3: integer (nullable = true)
#  |-- rleft-g0: integer (nullable = true)
#  |-- rleft-g1: integer (nullable = true)
#  |-- rleft-g2: integer (nullable = true)
#  |-- rleft-g3: integer (nullable = true)
#  |-- rrow-g0: integer (nullable = true)
#  |-- rrow-g1: double (nullable = true)
#  |-- rrow-g2: double (nullable = true)
#  |-- rrow-g3: integer (nullable = true)
#  |-- rcol-g0: integer (nullable = true)
#  |-- rcol-g1: integer (nullable = true)
#  |-- rcol-g2: integer (nullable = true)
#  |-- rcol-g3: integer (nullable = true)
#  |-- dist-g0: integer (nullable = true)
#  |-- dist-g1: integer (nullable = true)
#  |-- dist-g2: integer (nullable = true)
#  |-- dist-g3: integer (nullable = true)
#  |-- simg-g0: integer (nullable = true)
#  |-- simg-g1: integer (nullable = true)
#  |-- simg-g2: double (nullable = true)
#  |-- simg-g3: integer (nullable = true)
#  |-- mimg-g0: integer (nullable = true)
#  |-- mimg-g1: integer (nullable = true)
#  |-- mimg-g2: integer (nullable = true)
#  |-- mimg-g3: integer (nullable = true)
#  |-- limg-g0: integer (nullable = true)
#  |-- limg-g1: integer (nullable = true)
#  |-- limg-g2: integer (nullable = true)
#  |-- limg-g3: integer (nullable = true)
#  |-- aimg-g0: integer (nullable = true)
#  |-- aimg-g1: integer (nullable = true)
#  |-- aimg-g2: integer (nullable = true)
#  |-- aimg-g3: integer (nullable = true)
#  |-- saimg-g0: integer (nullable = true)
#  |-- saimg-g1: integer (nullable = true)
#  |-- saimg-g2: integer (nullable = true)
#  |-- saimg-g3: integer (nullable = true)
#  |-- maimg-g0: integer (nullable = true)
#  |-- maimg-g1: double (nullable = true)
#  |-- maimg-g2: integer (nullable = true)
#  |-- maimg-g3: double (nullable = true)
#  |-- laimg-g0: integer (nullable = true)
#  |-- laimg-g1: double (nullable = true)
#  |-- laimg-g2: integer (nullable = true)
#  |-- laimg-g3: double (nullable = true)
#  |-- char_max-g0: integer (nullable = true)
#  |-- char_max-g1: integer (nullable = true)
#  |-- char_max-g2: integer (nullable = true)
#  |-- char_max-g3: integer (nullable = true)
#  |-- char_ave-g0: double (nullable = true)
#  |-- char_ave-g1: double (nullable = true)
#  |-- char_ave-g2: double (nullable = true)
#  |-- char_ave-g3: double (nullable = true)
#  |-- own_char-g0: integer (nullable = true)
#  |-- own_char-g1: integer (nullable = true)
#  |-- own_char-g2: double (nullable = true)
#  |-- own_char-g3: double (nullable = true)
#  |-- own_txt_nd-g0: double (nullable = true)
#  |-- own_txt_nd-g1: double (nullable = true)
#  |-- own_txt_nd-g2: integer (nullable = true)
#  |-- own_txt_nd-g3: integer (nullable = true)
#  |-- grant_child-g0: integer (nullable = true)
#  |-- grant_child-g1: integer (nullable = true)
#  |-- grant_child-g2: integer (nullable = true)
#  |-- grant_child-g3: integer (nullable = true)
#  |-- descend-g0: integer (nullable = true)
#  |-- descend-g1: integer (nullable = true)
#  |-- descend-g2: double (nullable = true)
#  |-- descend-g3: integer (nullable = true)
#  |-- sep-g0: integer (nullable = true)
#  |-- sep-g1: integer (nullable = true)
#  |-- sep-g2: integer (nullable = true)
#  |-- sep-g3: integer (nullable = true)
#  |-- rseq-g0: integer (nullable = true)
#  |-- rseq-g1: integer (nullable = true)
#  |-- rseq-g2: double (nullable = true)
#  |-- rseq-g3: double (nullable = true)
#  |-- txt_nd_c-g0: integer (nullable = true)
#  |-- txt_nd_c-g1: integer (nullable = true)
#  |-- txt_nd_c-g2: integer (nullable = true)
#  |-- txt_nd_c-g3: integer (nullable = true)
#  |-- vcc-g0: integer (nullable = true)
#  |-- vcc-g1: integer (nullable = true)
#  |-- vcc-g2: integer (nullable = true)
#  |-- vcc-g3: integer (nullable = true)
#  |-- vcv-g0: integer (nullable = true)
#  |-- vcv-g1: integer (nullable = true)
#  |-- vcv-g2: integer (nullable = true)
#  |-- vcv-g3: double (nullable = true)
#  |-- avcc-g0: integer (nullable = true)
#  |-- avcc-g1: integer (nullable = true)
#  |-- avcc-g2: integer (nullable = true)
#  |-- avcc-g3: integer (nullable = true)
#  |-- avcv-g0: integer (nullable = true)
#  |-- avcv-g1: integer (nullable = true)
#  |-- avcv-g2: integer (nullable = true)
#  |-- avcv-g3: integer (nullable = true)
#  |-- hcc-g0: integer (nullable = true)
#  |-- hcc-g1: integer (nullable = true)
#  |-- hcc-g2: integer (nullable = true)
#  |-- hcc-g3: integer (nullable = true)
#  |-- hcv-g0: integer (nullable = true)
#  |-- hcv-g1: integer (nullable = true)
#  |-- hcv-g2: integer (nullable = true)
#  |-- hcv-g3: integer (nullable = true)
#  |-- ahcc-g0: integer (nullable = true)
#  |-- ahcc-g1: integer (nullable = true)
#  |-- ahcc-g2: double (nullable = true)
#  |-- ahcc-g3: integer (nullable = true)
#  |-- ahcv-g0: double (nullable = true)
#  |-- ahcv-g1: integer (nullable = true)
#  |-- ahcv-g2: integer (nullable = true)
#  |-- ahcv-g3: integer (nullable = true)
#  |-- txt_df-g0: integer (nullable = true)
#  |-- txt_df-g1: integer (nullable = true)
#  |-- txt_df-g2: double (nullable = true)
#  |-- txt_df-g3: integer (nullable = true)
#  |-- cap_df-g0: double (nullable = true)
#  |-- cap_df-g1: double (nullable = true)
#  |-- cap_df-g2: double (nullable = true)
#  |-- cap_df-g3: integer (nullable = true)
#  |-- tn_max_w-g0: integer (nullable = true)
#  |-- tn_max_w-g1: double (nullable = true)
#  |-- tn_max_w-g2: double (nullable = true)
#  |-- tn_max_w-g3: double (nullable = true)
#  |-- tn_ave_w-g0: double (nullable = true)
#  |-- tn_ave_w-g1: double (nullable = true)
#  |-- tn_ave_w-g2: double (nullable = true)
#  |-- tn_ave_w-g3: integer (nullable = true)
#  |-- tn_max_h-g0: integer (nullable = true)
#  |-- tn_max_h-g1: integer (nullable = true)
#  |-- tn_max_h-g2: integer (nullable = true)
#  |-- tn_max_h-g3: integer (nullable = true)
#  |-- tn_ave_h-g0: integer (nullable = true)
#  |-- tn_ave_h-g1: integer (nullable = true)
#  |-- tn_ave_h-g2: integer (nullable = true)
#  |-- tn_ave_h-g3: double (nullable = true)
#  |-- a_max_w-g0: integer (nullable = true)
#  |-- a_max_w-g1: integer (nullable = true)
#  |-- a_max_w-g2: integer (nullable = true)
#  |-- a_max_w-g3: integer (nullable = true)
#  |-- a_ave_w-g0: integer (nullable = true)
#  |-- a_ave_w-g1: integer (nullable = true)
#  |-- a_ave_w-g2: integer (nullable = true)
#  |-- a_ave_w-g3: double (nullable = true)
#  |-- a_max_h-g0: double (nullable = true)
#  |-- a_max_h-g1: integer (nullable = true)
#  |-- a_max_h-g2: integer (nullable = true)
#  |-- a_max_h-g3: integer (nullable = true)
#  |-- a_ave_h-g0: integer (nullable = true)
#  |-- a_ave_h-g1: integer (nullable = true)
#  |-- a_ave_h-g2: integer (nullable = true)
#  |-- a_ave_h-g3: integer (nullable = true)
#  |-- img_max_w-g0: integer (nullable = true)
#  |-- img_max_w-g1: integer (nullable = true)
#  |-- img_max_w-g2: integer (nullable = true)
#  |-- img_max_w-g3: integer (nullable = true)
#  |-- img_ave_w-g0: double (nullable = true)
#  |-- img_ave_w-g1: integer (nullable = true)
#  |-- img_ave_w-g2: integer (nullable = true)
#  |-- img_ave_w-g3: integer (nullable = true)
#  |-- img_max_h-g0: integer (nullable = true)
#  |-- img_max_h-g1: integer (nullable = true)
#  |-- img_max_h-g2: integer (nullable = true)
#  |-- img_max_h-g3: integer (nullable = true)
#  |-- img_ave_h-g0: integer (nullable = true)
#  |-- img_ave_h-g1: integer (nullable = true)
#  |-- img_ave_h-g2: integer (nullable = true)
#  |-- img_ave_h-g3: integer (nullable = true)
#  |-- tn_total_w-g0: integer (nullable = true)
#  |-- tn_total_w-g1: integer (nullable = true)
#  |-- tn_total_w-g2: integer (nullable = true)
#  |-- tn_total_w-g3: integer (nullable = true)
#  |-- tn_total_h-g0: integer (nullable = true)
#  |-- tn_total_h-g1: integer (nullable = true)
#  |-- tn_total_h-g2: integer (nullable = true)
#  |-- tn_total_h-g3: double (nullable = true)
#  |-- a_total_w-g0: integer (nullable = true)
#  |-- a_total_w-g1: double (nullable = true)
#  |-- a_total_w-g2: integer (nullable = true)
#  |-- a_total_w-g3: integer (nullable = true)
#  |-- a_total_h-g0: integer (nullable = true)
#  |-- a_total_h-g1: integer (nullable = true)
#  |-- a_total_h-g2: integer (nullable = true)
#  |-- a_total_h-g3: double (nullable = true)
#  |-- img_total_w-g0: integer (nullable = true)
#  |-- img_total_w-g1: double (nullable = true)
#  |-- img_total_w-g2: double (nullable = true)
#  |-- img_total_w-g3: double (nullable = true)
#  |-- img_total_h-g0: integer (nullable = true)
#  |-- img_total_h-g1: integer (nullable = true)
#  |-- img_total_h-g2: double (nullable = true)
#  |-- img_total_h-g3: double (nullable = true)
#  |-- text: string (nullable = true)
#  |-- url: string (nullable = true)

# %%
df.toDF()
# Out:
# ---------------------------------------------------------------------------
# IllegalArgumentException                  Traceback (most recent call last)
# Cell In[256], line 1
# ----> 1 df.toDF()
#
# File D:\Users\pereg\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyspark\sql\dataframe.py:5486, in DataFrame.toDF(self, *cols)
#    5481     if not isinstance(col, str):
#    5482         raise PySparkTypeError(
#    5483             error_class="NOT_LIST_OF_STR",
#    5484             message_parameters={"arg_name": "cols", "arg_type": type(col).__name__},
#    5485         )
# -> 5486 jdf = self._jdf.toDF(self._jseq(cols))
#    5487 return DataFrame(jdf, self.sparkSession)
#
# File D:\Users\pereg\AppData\Local\Programs\Python\Python311\Lib\site-packages\py4j\java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File D:\Users\pereg\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyspark\errors\exceptions\captured.py:185, in capture_sql_exception.<locals>.deco(*a, **kw)
#     181 converted = convert_exception(e.java_exception)
#     182 if not isinstance(converted, UnknownException):
#     183     # Hide where the exception came from that shows a non-Pythonic
#     184     # JVM exception message.
# --> 185     raise converted from None
#     186 else:
#     187     raise
#
# IllegalArgumentException: requirement failed: The number of columns doesn't match.
# Old column names (279): label, top-g0, top-g1, top-g2, top-g3, left-g0, left-g1, left-g2, left-g3, width-g0, width-g1, width-g2, width-g3, height-g0, height-g1, height-g2, height-g3, char-g0, char-g1, char-g2, char-g3, txt_nd-g0, txt_nd-g1, txt_nd-g2, txt_nd-g3, img-g0, img-g1, img-g2, img-g3, a-g0, a-g1, a-g2, a-g3, sibling-g0, sibling-g1, sibling-g2, sibling-g3, child-g0, child-g1, child-g2, child-g3, dep-g0, dep-g1, dep-g2, dep-g3, seq-g0, seq-g1, seq-g2, seq-g3, txt_dns-g0, txt_dns-g1, txt_dns-g2, txt_dns-g3, pid-g0, pid-g1, pid-g2, pid-g3, tag-g0, tag-g1, tag-g2, tag-g3, nd_id-g0, nd_id-g1, nd_id-g2, nd_id-g3, nd_cs-g0, nd_cs-g1, nd_cs-g2, nd_cs-g3, ft_sz-g0, ft_sz-g1, ft_sz-g2, ft_sz-g3, color-g0, color-g1, color-g2, color-g3, b_bolor-g0, b_bolor-g1, b_bolor-g2, b_bolor-g3, rtop-g0, rtop-g1, rtop-g2, rtop-g3, rleft-g0, rleft-g1, rleft-g2, rleft-g3, rrow-g0, rrow-g1, rrow-g2, rrow-g3, rcol-g0, rcol-g1, rcol-g2, rcol-g3, dist-g0, dist-g1, dist-g2, dist-g3, simg-g0, simg-g1, simg-g2, simg-g3, mimg-g0, mimg-g1, mimg-g2, mimg-g3, limg-g0, limg-g1, limg-g2, limg-g3, aimg-g0, aimg-g1, aimg-g2, aimg-g3, saimg-g0, saimg-g1, saimg-g2, saimg-g3, maimg-g0, maimg-g1, maimg-g2, maimg-g3, laimg-g0, laimg-g1, laimg-g2, laimg-g3, char_max-g0, char_max-g1, char_max-g2, char_max-g3, char_ave-g0, char_ave-g1, char_ave-g2, char_ave-g3, own_char-g0, own_char-g1, own_char-g2, own_char-g3, own_txt_nd-g0, own_txt_nd-g1, own_txt_nd-g2, own_txt_nd-g3, grant_child-g0, grant_child-g1, grant_child-g2, grant_child-g3, descend-g0, descend-g1, descend-g2, descend-g3, sep-g0, sep-g1, sep-g2, sep-g3, rseq-g0, rseq-g1, rseq-g2, rseq-g3, txt_nd_c-g0, txt_nd_c-g1, txt_nd_c-g2, txt_nd_c-g3, vcc-g0, vcc-g1, vcc-g2, vcc-g3, vcv-g0, vcv-g1, vcv-g2, vcv-g3, avcc-g0, avcc-g1, avcc-g2, avcc-g3, avcv-g0, avcv-g1, avcv-g2, avcv-g3, hcc-g0, hcc-g1, hcc-g2, hcc-g3, hcv-g0, hcv-g1, hcv-g2, hcv-g3, ahcc-g0, ahcc-g1, ahcc-g2, ahcc-g3, ahcv-g0, ahcv-g1, ahcv-g2, ahcv-g3, txt_df-g0, txt_df-g1, txt_df-g2, txt_df-g3, cap_df-g0, cap_df-g1, cap_df-g2, cap_df-g3, tn_max_w-g0, tn_max_w-g1, tn_max_w-g2, tn_max_w-g3, tn_ave_w-g0, tn_ave_w-g1, tn_ave_w-g2, tn_ave_w-g3, tn_max_h-g0, tn_max_h-g1, tn_max_h-g2, tn_max_h-g3, tn_ave_h-g0, tn_ave_h-g1, tn_ave_h-g2, tn_ave_h-g3, a_max_w-g0, a_max_w-g1, a_max_w-g2, a_max_w-g3, a_ave_w-g0, a_ave_w-g1, a_ave_w-g2, a_ave_w-g3, a_max_h-g0, a_max_h-g1, a_max_h-g2, a_max_h-g3, a_ave_h-g0, a_ave_h-g1, a_ave_h-g2, a_ave_h-g3, img_max_w-g0, img_max_w-g1, img_max_w-g2, img_max_w-g3, img_ave_w-g0, img_ave_w-g1, img_ave_w-g2, img_ave_w-g3, img_max_h-g0, img_max_h-g1, img_max_h-g2, img_max_h-g3, img_ave_h-g0, img_ave_h-g1, img_ave_h-g2, img_ave_h-g3, tn_total_w-g0, tn_total_w-g1, tn_total_w-g2, tn_total_w-g3, tn_total_h-g0, tn_total_h-g1, tn_total_h-g2, tn_total_h-g3, a_total_w-g0, a_total_w-g1, a_total_w-g2, a_total_w-g3, a_total_h-g0, a_total_h-g1, a_total_h-g2, a_total_h-g3, img_total_w-g0, img_total_w-g1, img_total_w-g2, img_total_w-g3, img_total_h-g0, img_total_h-g1, img_total_h-g2, img_total_h-g3, text, url
# New column names (0):

# %%
from pyspark.mllib.feature import StandardScaler

scaler = StandardScaler(withStd=True, withMean=False)

# Compute summary statistics by fitting the StandardScaler
scalerModel = scaler.fit(df)
